# %% [markdown]
# In this notebook, we'll be running a simple linear regression with scikit-learn. The dataset is from the [Kaggle Used Car Prices Barcelona 2022 set](https://www.kaggle.com/datasets/erenakbulut/user-car-prices-barcelona-2022).

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Load the data and ignore the first row and the first column
arr = np.loadtxt("data/`used_cars_data.csv",
                 delimiter=",", dtype=str, skiprows=1)[:,1:]

# Rearrange columns so that index #2 is at the end
i = [0,1,3,4,5,6,7,8,2]
arr = arr[:,i]

# %%
# Extract the the mileage column as X and the price column as Y
X, Y = arr[:,4].astype(int), arr[:,8].astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test.reshape(-1, 1))

# %%
plt.scatter(X_train.reshape(-1,1), y_train, color = 'red')
plt.plot(X_train.reshape(-1,1), regressor.predict(X_train.reshape(-1,1)), color = 'blue')
plt.title('Mileage vs Price (Training set)')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.show()
